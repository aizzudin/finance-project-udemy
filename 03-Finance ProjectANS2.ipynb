# %%
pip install pandas-datareader
# Out:
# ...
#      |████████████████████████████████| 107 kB 8.6 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 5.7 MB 11.8 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 10.1 MB 26.9 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 509 kB 24.9 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 20.1 MB 24.0 MB/s eta 0:00:01     |████████████████████████████    | 17.6 MB 24.0 MB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install seaborn
# Out:
# ...
#      |████████████████████████████████| 215 kB 7.7 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 26.1 MB 11.1 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 13.1 MB 23.3 MB/s eta 0:00:01    |██████████████████              | 7.4 MB 23.3 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 67 kB 9.1 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 90 kB 14.4 MB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from pandas_datareader import data, wb
import pandas as pd
import numpy as np
import datetime
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
start = datetime.datetime(2006,1,1)
end = datetime.datetime(2016,1,1)

# %%
BAC = data.DataReader('BAC','yahoo',start, end)
C = data.DataReader('C','yahoo',start, end)
GS = data.DataReader('GS','yahoo',start, end)
JPM = data.DataReader('JPM','yahoo',start, end)
MS = data.DataReader('MS','yahoo',start, end)
WFC = data.DataReader('WFC','yahoo',start, end)

# %%
ticker=['BAC','C','GS','JPM','MS','WFC']

# %%
bdata = pd.concat([BAC,C,GS,JPM,MS,WFC], axis=1, keys=ticker)

bdata.head()
# Out:
#                   BAC                                                          \
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2006-01-03  47.180000  46.150002  46.919998  47.080002  16296700.0  35.523922
# 2006-01-04  47.240002  46.450001  47.000000  46.580002  17757900.0  35.146645
# 2006-01-05  46.830002  46.320000  46.580002  46.639999  14970700.0  35.191933
# 2006-01-06  46.910000  46.349998  46.799999  46.570000  12599800.0  35.139107
# 2006-01-09  46.970001  46.360001  46.720001  46.599998  15619400.0  35.161732
#
#                      C                                      ...         MS  \
#                   High         Low        Open       Close  ...       Open
# Date                                                        ...
# 2006-01-03  493.799988  481.100006  490.000000  492.899994  ...  57.169998
# 2006-01-04  491.000000  483.500000  488.600006  483.799988  ...  58.700001
# ...

# %%
bdata.columns.names = ['Bank Ticker', 'Stock Info']

bdata.head()
# Out:
# Bank Ticker        BAC                                               \
# Stock Info        High        Low       Open      Close      Volume
# Date
# 2006-01-03   47.180000  46.150002  46.919998  47.080002  16296700.0
# 2006-01-04   47.240002  46.450001  47.000000  46.580002  17757900.0
# 2006-01-05   46.830002  46.320000  46.580002  46.639999  14970700.0
# 2006-01-06   46.910000  46.349998  46.799999  46.570000  12599800.0
# 2006-01-09   46.970001  46.360001  46.720001  46.599998  15619400.0
#
# Bank Ticker                      C                                      ...  \
# Stock Info   Adj Close        High         Low        Open       Close  ...
# Date                                                                    ...
# 2006-01-03   35.523922  493.799988  481.100006  490.000000  492.899994  ...
# 2006-01-04   35.146645  491.000000  483.500000  488.600006  483.799988  ...
# 2006-01-05   35.191933  487.799988  484.000000  484.399994  486.200012  ...
# ...

# %%
bdata.xs(key='Close', axis = 1, level=1).max()
# Out:
# Bank Ticker
# BAC     54.900002
# C      564.099976
# GS     247.919998
# JPM     70.080002
# MS      89.300003
# WFC     58.520000
# dtype: float64

# %%
returns = pd.DataFrame()

# %%
for tick in ticker:
    returns[tick + " Return"] = bdata[tick]['Close'].pct_change()
    
    
returns.head()
# Out:
#             BAC Return  C Return  GS Return  JPM Return  MS Return  WFC Return
# Date
# 2006-01-03         NaN       NaN        NaN         NaN        NaN         NaN
# 2006-01-04   -0.010620 -0.018462  -0.013812   -0.014183   0.000686   -0.011599
# 2006-01-05    0.001288  0.004961  -0.000393    0.003029   0.002742   -0.001110
# 2006-01-06   -0.001501  0.000000   0.014169    0.007046   0.001025    0.005874
# 2006-01-09    0.000644 -0.004731   0.012030    0.016242   0.010586   -0.000158

# %%
sns.set_style('whitegrid')
sns.pairplot(returns)

# %%
returns.idxmin()
# Out:
# BAC Return   2009-01-20
# C Return     2009-02-27
# GS Return    2009-01-20
# JPM Return   2009-01-20
# MS Return    2008-10-09
# WFC Return   2009-01-20
# dtype: datetime64[ns]

# %%
returns.idxmax()
# Out:
# BAC Return   2009-04-09
# C Return     2008-11-24
# GS Return    2008-11-24
# JPM Return   2009-01-21
# MS Return    2008-10-13
# WFC Return   2008-07-16
# dtype: datetime64[ns]

# %%
returns.std()
# Out:
# BAC Return    0.036647
# C Return      0.038672
# GS Return     0.025390
# JPM Return    0.027667
# MS Return     0.037819
# WFC Return    0.030238
# dtype: float64

# %%
returns.loc['2015-01-01':'2015-12-31'].std()
# Out:
# BAC Return    0.016163
# C Return      0.015289
# GS Return     0.014046
# JPM Return    0.014017
# MS Return     0.016249
# WFC Return    0.012591
# dtype: float64

# %%
plt.figure(figsize=(6,6))
sns.distplot(returns.loc['2015-01-01':'2015-12-31']['MS Return'], color='g', bins=50)

# %%
plt.figure(figsize=(6,6))
sns.distplot(returns.loc['2008-01-01':'2008-12-31']['C Return'], color='r', bins=50)

# %%
pip install plotly
# Out:
# ...
#      |████████████████████████████████| 7.1 MB 4.9 MB/s eta 0:00:01
# ...
#   Created wheel for retrying: filename=retrying-1.3.3-py3-none-any.whl size=11429 sha256=fbfc54b304fc646b3398a3622fba3359264b96ce524ea75a61260aed3f1ba9bc
#   Stored in directory: /home/jovyan/.cache/pip/wheels/f9/8d/8d/f6af3f7f9eea3553bc2fe6d53e4b287dad18b06a861ac56ddf
# Successfully built retrying
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install cufflinks
# Out:
# ...
#      |████████████████████████████████| 81 kB 3.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 76 kB 5.3 MB/s eta 0:00:011
# ...
#   Created wheel for cufflinks: filename=cufflinks-0.17.0-py3-none-any.whl size=67743 sha256=b79ff686a04a951855d7cf1e85e1f68db0761fcfb0080f486f2b2b95346b2ebb
#   Stored in directory: /home/jovyan/.cache/pip/wheels/16/22/f8/084326defc3fe232aacf4a4c855c58de34b62f35387acc1eda
# Successfully built cufflinks
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import plotly
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
for tick in ticker:
    bdata[tick]['Close'].plot(figsize = (14,5))

plt.legend(ticker)

# %%
bdata.xs(key='Close', axis=1, level='Stock Info').plot(figsize=(14,5))

# %%
bdata.xs(key='Close', axis=1, level='Stock Info').iplot()
# Out:
# <div>
#
#
#             <div id="1e5343ff-2e2a-4dc3-8591-d65efff0e07a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("1e5343ff-2e2a-4dc3-8591-d65efff0e07a")) {
#                     Plotly.newPlot(
#                         '1e5343ff-2e2a-4dc3-8591-d65efff0e07a',
# ...

# %%
plt.figure(figsize= (14,5))
bdata['BAC']['Close'].loc['2008-01-01':'2008-12-31'].rolling(window=30).mean().plot()
bdata['BAC']['Close'].loc['2008-01-01':'2008-12-31'].plot()

plt.legend(['30 Day Avg', 'BAC CLOSE'])

# %%
bdata['BAC']['Close'].loc['2008-01-01':'2008-12-31'].rolling(window=30).mean().iplot()
bdata['BAC']['Close'].loc['2008-01-01':'2008-12-31'].iplot()
# Out:
# <div>
#
#
#             <div id="7f95899d-882f-46fd-9173-3a46e9876ae7" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("7f95899d-882f-46fd-9173-3a46e9876ae7")) {
#                     Plotly.newPlot(
#                         '7f95899d-882f-46fd-9173-3a46e9876ae7',
# ...

# %%
bdata.head()
# Out:
# Bank Ticker        BAC                                               \
# Stock Info        High        Low       Open      Close      Volume
# Date
# 2006-01-03   47.180000  46.150002  46.919998  47.080002  16296700.0
# 2006-01-04   47.240002  46.450001  47.000000  46.580002  17757900.0
# 2006-01-05   46.830002  46.320000  46.580002  46.639999  14970700.0
# 2006-01-06   46.910000  46.349998  46.799999  46.570000  12599800.0
# 2006-01-09   46.970001  46.360001  46.720001  46.599998  15619400.0
#
# Bank Ticker                      C                                      ...  \
# Stock Info   Adj Close        High         Low        Open       Close  ...
# Date                                                                    ...
# 2006-01-03   35.523922  493.799988  481.100006  490.000000  492.899994  ...
# 2006-01-04   35.146645  491.000000  483.500000  488.600006  483.799988  ...
# 2006-01-05   35.191933  487.799988  484.000000  484.399994  486.200012  ...
# ...

# %%
sns.heatmap(bdata.xs(key='Close', axis=1, level='Stock Info').corr(), cmap='RdBu_r', annot=True)

# %%
sns.clustermap(bdata.xs(key='Close', axis=1, level='Stock Info').corr(), cmap='RdBu_r', annot=True)

# %%
close_corr = bdata.xs(key='Close',axis=1,level='Stock Info').corr()
close_corr.iplot(kind='heatmap',colorscale='rdylbu')
# Out:
# <div>
#
#
#             <div id="6446c09c-e056-44f2-b7ae-7b98f6fd1e55" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("6446c09c-e056-44f2-b7ae-7b98f6fd1e55")) {
#                     Plotly.newPlot(
#                         '6446c09c-e056-44f2-b7ae-7b98f6fd1e55',
# ...
